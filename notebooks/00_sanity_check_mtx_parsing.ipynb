# %% [markdown]
# # Notebook 00 – Sanity check for MTX parsing
#
# This notebook demonstrates how to parse a Matrix Market (`.mtx`) file and build a networkx graph using the helper functions provided in the `dss` package.  Run the cell below after adjusting the file path to your `.mtx` file.

# %%
from dss.utils.io_mtx import load_mtx
from dss.graph.build_graph import build_graph

# TODO: replace with the path to your .mtx file
file_path = 'data/example.mtx'
A = load_mtx(file_path)
G = build_graph(A)
print(f'Loaded graph with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges')
