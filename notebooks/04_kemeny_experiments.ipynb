# %% [markdown]
# # Notebook 04 – Kemeny constant experiments
#
# This notebook demonstrates how to compute the Kemeny constant of a graph
# using the implementation in `dss.analytics.kemeny`.  It also illustrates
# the effect of removing nodes on the Kemeny constant.
