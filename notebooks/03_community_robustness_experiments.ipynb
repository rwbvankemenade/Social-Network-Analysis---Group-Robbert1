# %% [markdown]
# # Notebook 03 – Community robustness experiments
#
# This notebook illustrates the use of community detection algorithms and
# robustness testing by removing random edges from the graph.  The functions
# implemented in `dss.analytics.communities` and
# `dss.analytics.robustness` form the backbone of the analyses.
