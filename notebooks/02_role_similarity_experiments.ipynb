# %% [markdown]
# # Notebook 02 – Role similarity experiments
#
# Use this notebook to explore the construction of role signatures and
# similarity matrices, and to apply clustering methods (hierarchical
# clustering, spectral clustering, etc.) on the role similarity matrix.
# Refer to `dss.analytics.roles` for the implementation details.
