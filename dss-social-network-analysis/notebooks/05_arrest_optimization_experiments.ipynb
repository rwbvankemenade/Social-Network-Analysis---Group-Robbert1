# %% [markdown]
# # Notebook 05 – Arrest optimisation experiments
#
# This notebook shows how to use the arrest assignment model implemented in
# `dss.analytics.arrest_optimization` to allocate network members to two
# departments.  Both exact ILP and heuristic solutions can be tested here,
# along with different regret and penalty parameters.
